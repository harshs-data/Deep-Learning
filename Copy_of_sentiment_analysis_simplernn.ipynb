# %% [markdown]
# <a href="https://colab.research.google.com/github/harshs-data/Deep-Learning/blob/main/Copy_of_sentiment_analysis_simplernn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten
model = Sequential()
model.add(Embedding(17,output_dim=2,input_length=5))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 859ms/step
# [[[-0.00673574 -0.043398  ]
#   [ 0.02910883 -0.00505413]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[ 0.02910883 -0.00505413]
#   [ 0.02910883 -0.00505413]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[ 0.04190693  0.01956597]
#   [ 0.04190693  0.01956597]
#   [ 0.04890743 -0.0092387 ]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[ 0.04447475  0.04897803]
#   [ 0.00621007  0.01941767]
#   [ 0.04447475  0.04897803]
#   [ 0.02910883 -0.00505413]
#   [ 0.04447475  0.04897803]]
#
#  [[ 0.02612538  0.00773759]
#   [ 0.047609   -0.03534515]
#   [ 0.00271068  0.00387783]
#   [-0.02171192 -0.01261006]
#   [ 0.0432432  -0.03716757]]
#
#  [[-0.04579021 -0.0079355 ]
#   [-0.04579021 -0.0079355 ]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[-0.02646374 -0.01274456]
#   [-0.02646374 -0.01274456]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[ 0.04739792  0.03790485]
#   [ 0.04739792  0.03790485]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]
#
#  [[-0.0071008   0.02179989]
#   [-0.00591799 -0.0406276 ]
#   [ 0.00271068  0.00387783]
#   [-0.02171192 -0.01261006]
#   [ 0.0432432  -0.03716757]]
#
#  [[ 0.01472503  0.02700688]
#   [ 0.01472503  0.02700688]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]
#   [ 0.0432432  -0.03716757]]]

# %%
from keras.datasets import imdb
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4464/2928721732.py in <cell line: 0>()
#       1 from keras.datasets import imdb
# ----> 2 from keras.preprocessing.text import Tokenizer
#       3 from keras.utils import pad_sequences
#       4 from keras import Sequential
#       5 from keras.layers import Dense,SimpleRNN,Embedding,Flatten
#
# ModuleNotFoundError: No module named 'keras.preprocessing.text'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Embedding(10000, 2,50))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4464/3568153921.py in <cell line: 0>()
#       1 model = Sequential()
# ----> 2 model.add(Embedding(10000, 2,50))
#       3 model.add(SimpleRNN(32,return_sequences=False))
#       4 model.add(Dense(1, activation='sigmoid'))
#       5
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py in __init__(self, input_dim, output_dim, embeddings_initializer, embeddings_regularizer, embeddings_constraint, mask_zero, weights, lora_rank, lora_alpha, quantization_config, **kwargs)
#     104         self.input_dim = input_dim
#     105         self.output_dim = output_dim
# --> 106         self.embeddings_initializer = initializers.get(embeddings_initializer)
#     107         self.embeddings_regularizer = regularizers.get(embeddings_regularizer)
#     108         self.embeddings_constraint = constraints.get(embeddings_constraint)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/initializers/__init__.py in get(identifier)
#     159         return obj
#     160     else:
# --> 161         raise ValueError(
#     162             f"Could not interpret initializer identifier: {identifier}"
#     163         )
#
# ValueError: Could not interpret initializer identifier: 50

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
